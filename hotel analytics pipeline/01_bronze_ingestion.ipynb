# %%
spark.sql("CREATE DATABASE IF NOT EXISTS hotel_bronze")
df = spark.table("hotel_bookings")
df.show(5)
df.printSchema()

df.write.format("delta") \
  .mode("overwrite") \
  .saveAsTable("hotel_bronze.bookings_raw")
